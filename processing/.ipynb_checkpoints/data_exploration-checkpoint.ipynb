# %%
import sys
sys.path.insert(0, './src/results')
import numpy as np
from utils import nicename, nicephn, PHNALL
from load import load_all_p1, load_all_p2
import pandas as pd

data = load_all_p2(clear_badlines=True, add_bleu=True)
dataP1 = load_all_p1()
data['sev'] = data.apply(lambda row: sum([0 if np.isnan(row[phnName]) else row[phnName] for phnName in PHNALL]), axis=1)
# Out:
# Loading data
# Removing bad lines
# Computing BLEU
# Loading data

# %%
pd.options.display.max_colwidth = 90
pd.options.display.max_rows = 70

# %%
data[(data['role']>=0.5)][['txt_tgt', 'sev', 'bleu', 'mkb', 'role']]
# Out:
#                                                                                         txt_tgt  \
# 302   The agreement on the cooperation of supreme audit institutions of the Czech Republic (...
# 2046  Since both Contracting parties are interested in continuing the relationship establish...
# 4167                 The inspection carried out also contained elements of a performance audit.
# 4221  This cooperation took a form of parallel control, whereby the inspection authorities i...
# 5331  „Jak se opovažuješ?“ Thunbergův projev v OSN inspiruje nizozemské klimatické demonstranty
# 5332  'Jak se opovažuješ?' Thunbergova řeč U.N. inspiruje nizozemské protestující proti změn...
# 5333  „Jak se opovažuješ?“ Thunbergův projev v OSN inspiruje nizozemské klimatické demonstranty
# 5335    "Jak se opovažuješ?" Thunbergův projev OSN inspiruje nizozemské klimatické demonstranty
# 5338           „Jak se opovažuješ?“ Thunbergův projev v OSN inspiruje holandské odpůrce klimatu
# 5339  'Jak se opovažuješ?' Thunbergův projev v OSN inspiruje holandské protestující proti kl...
# 5340      Jak se opovažuješ?'Thunbergův projev OSN inspiruje Nizozemské klimatické demonstranty
# 5341          „Jak se opovažuješ?“ Thunbergův projev v OSN inspiroval holandské odpůrce klimatu
# 5342    Jak se opovažuješ? ' Thunbergův projev OSN inspiruje nizozemské klimatické protestující
# 5343  Tisíce holandských dětí přeskočily školu, aby se připojily k globálnímu klimatickému ú...
# 5346  Tisíce nizozemských dětí v pátek vynechaly školu, aby se připojily ke globální klimati...
# 5348  Tisíce nizozemských dětí vynechaly školu, aby se v pátek připojily ke globální klimati...
# 5352  Tisíce nizozemských dětí vynechaly školu, aby se v pátek připojily ke globální stávce ...
# 5353  Tisíce nizozemců dětí se školou, aby se připojit ke globální klimatické stávku v pátek...
# 5355  Tisíce nizozemských dětí vynechaly školu, aby se v pátek připojily ke globální stávce ...
# 5357  „Všechno je špatně. Neměla bych tu být. Měla bych být zpátky ve škole na druhé straně ...
# 5359  „Všechno je to špatně. Neměl bych tu být. Měl bych být zpátky ve škole na druhé straně...
# 5361  "Tohle všechno je špatně. Neměl bych tu být. Měl bych být zpátky ve škole na druhé str...
# 5362  „To je všechno špatně. Neměla bych být tady nahoře. Měla bych být zpátky ve škole na d...
# 5363  „Všechno je špatně. Neměl bych tu být. Měl bych být zpátky ve škole na druhé straně oc...
# 5364  „Všechno je špatně. Neměl bych tu být. Měl bych být zpátky ve škole na druhé straně oc...
# 5365  „Tohle všechno je špatně. Neměla bych tu být. Měl bych být zpátky ve škole na druhé st...
# 5366  "Tohle všechno je špatně. Neměl bych tu být. Měl bych být zpátky ve škole na druhé str...
# 5367  „Tohle všechno je špatně. Neměl bych tu být. Měl bych být zpátky ve škole na druhé str...
# 5368  ′′ Tohle je všechno špatně. Neměl bych tu být. Měl bych být zpátky ve škole na druhé s...
#
#        sev        bleu       mkb  role
# 302   0.75   33.714569   supreme  0.75
# 2046  0.50  100.000000     party  0.50
# 4167  1.25   11.530568  kontrola  0.75
# 4221  1.75    2.278088  kontrola  0.50
# 5331  1.00    4.259206      dare  0.50
# 5332  1.00   12.044026      dare  0.50
# 5333  1.00    4.259206      dare  0.50
# 5335  1.00    3.433102      dare  0.50
# 5338  1.00    4.259206      dare  0.50
# 5339  1.00   10.648826      dare  0.50
# 5340  1.00    4.039488      dare  0.50
# 5341  1.00    8.666613      dare  0.50
# 5342  1.00    4.340713      dare  0.50
# 5343  2.50    4.773048      dare  0.50
# 5346  2.00   24.806802      dare  0.50
# 5348  1.00   18.862699      dare  0.50
# 5352  1.00   30.143875      dare  0.50
# 5353  1.00   22.246188      dare  0.50
# 5355  1.00   16.786443      dare  0.50
# 5357  1.00   48.954485      dare  0.50
# 5359  1.00   47.976719      dare  0.50
# 5361  1.00   41.993358      dare  0.50
# 5362  1.00   46.598392      dare  0.50
# 5363  1.00   39.809513      dare  0.50
# 5364  1.00   39.809513      dare  0.50
# 5365  1.00   52.869778      dare  0.50
# 5366  1.00   35.104209      dare  0.50
# 5367  1.00   38.129303      dare  0.50
# 5368  1.00   42.508711      dare  0.50

# %%
index = 302
print(data.loc[index])
print(data.loc[index]['txt_ref'])
print(data.loc[index]['txt_tgt'])
# Out:
# user                                                                               broukc-0
# doc                                                                                  broukc
# domain                                                                                audit
# mkb                                                                                kontrola
# model                                                                            UEDIN-CUNI
# line                                                                                     27
# mkbIndex                                                                                  1
# txt_ref                         The completed audit had also elements of performance audit.
# txt_tgt          The inspection carried out also contained elements of a performance audit.
# lang                                                                                     en
# tootranslated                                                                           NaN
# disappearance                                                                           NaN
# typography                                                                              NaN
# style                                                                                   NaN
# nontranslated                                                                           NaN
# terminology                                                                             NaN
# inconsistency                                                                           NaN
# sense                                                                                   0.5
# role                                                                                   0.75
# grammar                                                                                 NaN
# conflict                                                                                NaN
# bleu                                                                                11.5306
# sev                                                                                    1.25
# Name: 4167, dtype: object
# The completed audit had also elements of performance audit.
# The inspection carried out also contained elements of a performance audit.

# %%
dataP1[(dataP1['line'] == 8) & (dataP1['doc'] == 'kufrc') & (dataP1['model'] == 'Online-G')]
# Out:
#          user    doc  line     model  \
# 1495  kufrc-1  kufrc     8  Online-G
# 1879  kufrc-0  kufrc     8  Online-G
#
#                                                 txt_ref  \
# 1495  In Art. III of the Sublease agreement, entitle...
# 1879  In Art. III of the Sublease agreement, entitle...
#
#                                                 txt_tgt lang  errors domain  \
# 1495  In art. III of the apartment lease agreement, ...   en       2  lease
# 1879  In art. III of the apartment lease agreement, ...   en       0  lease
#
#       fluency  adequacy  mult
# 1495      0.9       0.8  0.72
# 1879      0.7       0.5  0.35

# %%
SEARCH_STRING = 'In art. III of the apartment lease agreement, ca'
SEARCH_STRING = SEARCH_STRING.replace(r'\niceuline{', '').replace('}', '')
data[data['txt_tgt'].str.contains(SEARCH_STRING)][PHNALL+['mkb', 'line', 'user', 'bleu']]
# dataP1[dataP1['txt_tgt'].str.contains(SEARCH_STRING)]
# Out:
#       disappearance  typography  sense  style  terminology  inconsistency  \
# 1521            NaN         NaN    NaN    NaN          NaN            NaN
# 1547            NaN        0.25    NaN    NaN          NaN            NaN
# 1625            NaN         NaN    NaN    NaN          NaN            NaN
# 1937            NaN         NaN   0.25    NaN         0.50            NaN
# 1989            NaN         NaN    NaN    NaN          NaN            NaN
# 2275            NaN         NaN    NaN    NaN         0.50            NaN
# 2288            NaN         NaN    NaN    NaN          NaN            NaN
# 2379            1.0         NaN    NaN    NaN          NaN            NaN
# 2919            1.0         NaN    NaN    NaN          NaN            NaN
# 3049            NaN        0.25    NaN    NaN          NaN            NaN
# 3192            NaN         NaN    NaN    NaN         0.25            NaN
# 3205            NaN         NaN    NaN    NaN          NaN            NaN
# 3335            NaN         NaN    NaN    NaN          NaN            NaN
# 3517            NaN         NaN    NaN    NaN          NaN            NaN
# 3582            NaN         NaN    NaN    NaN          NaN            NaN
# 3634            NaN         NaN    NaN    NaN          NaN            NaN
#
#       nontranslated  conflict  grammar  role  tootranslated           mkb  \
# 1521            NaN       NaN      NaN   NaN            NaN           III
# 1547            NaN       NaN      NaN   NaN            NaN            čl
# 1625            NaN       NaN      NaN   NaN            NaN     nájemkyně
# 1937            NaN      1.00     0.25   NaN            NaN  podnájemkyně
# 1989            NaN       NaN      NaN   NaN            NaN  podnájemkyně
# 2275            NaN      1.00      NaN   NaN            NaN      podnájmu
# 2288            NaN       NaN      NaN   NaN            NaN      podnájmu
# 2379            NaN       NaN      NaN   NaN            NaN     předmětný
# 2919            NaN       NaN      NaN   NaN            NaN     předmětný
# 3049            NaN       NaN      NaN   NaN            NaN            čl
# 3192            NaN       NaN      NaN   NaN            NaN      podnájmu
# 3205            NaN       NaN      NaN   NaN            NaN      podnájmu
# 3335            NaN       NaN      NaN   NaN            NaN     nájemkyně
# 3517            NaN       NaN      NaN   NaN            NaN           III
# 3582            NaN      0.75      NaN   NaN            NaN  podnájemkyně
# 3634            NaN       NaN      NaN   NaN            NaN  podnájemkyně
#
#       line     user       bleu
# 1521     8  kufrc-1  51.064068
# 1547     8  kufrc-1  51.064068
# 1625     8  kufrc-1  51.064068
# 1937     8  kufrc-1  51.064068
# 1989     8  kufrc-1  51.064068
# 2275     8  kufrc-1  51.064068
# 2288     8  kufrc-1  51.064068
# 2379     8  kufrc-1  51.064068
# 2919     8  kufrc-0  51.064068
# 3049     8  kufrc-0  51.064068
# 3192     8  kufrc-0  51.064068
# 3205     8  kufrc-0  51.064068
# 3335     8  kufrc-0  51.064068
# 3517     8  kufrc-0  51.064068
# 3582     8  kufrc-0  51.064068
# 3634     8  kufrc-0  51.064068
